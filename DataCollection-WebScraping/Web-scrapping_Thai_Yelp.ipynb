# %% [markdown]
# ## Data Collection using BeautifulSoup to pull Thai Restaurant Information from Yelp

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
url='https://www.yelp.com/search?cflt=thai&find_loc=San%20Francisco%2C%20CA&sortby=review_count'
page=requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')

# %%
names=[]
categories=[]
review_count=[]
ratings=[]
price=[]
allchunk= soup.find_all("div",{"class":"media-story"})
for chunk in allchunk:
    if chunk.find("h3",{"class":"search-result-title"})!=None:
        if chunk.h3.find("span",{"class":"yloca-tip"})==None:#not Ad
            names.append(chunk.h3.a.span.get_text().strip())       
        # Get the numbers of reviews
            link=chunk.find("span",{"class":"review-count rating-qualifier"})
            if link!=None:
                review_count.append(int(link.get_text().strip().split()[0]))
            else:
                review_count.append(np.nan)
        # Get the star ratings
            link=chunk.find("div",{"class":"biz-rating biz-rating-large clearfix"})
            if link!=None:
                ratings.append(float(link.img['alt'].split()[0]))
            else:
                ratings.append(np.nan)
        # Get price
            link=chunk.find("span",{"class":"business-attribute price-range"})
            if link!=None:
                price.append(link.get_text().strip())
            else:
                price.append(np.nan)
        # Get category
            link=chunk.find("span",{"class":"category-str-list"})
            if link!=None:
                cat=link.get_text().strip().split(",")
                newcat=(",").join([i.strip(' \t\n\r') for i in cat])
                categories.append(newcat)
            else:
                categories.append(np.nan)
print(names[0],review_count[0],ratings[0],price[0],categories[0])
i=0
while (i<4):
    try:
        i+=1
        ttag=soup.find_all('a',{'class':'u-decoration-none next pagination-links_anchor'})
        next_url='https://www.yelp.com'+ttag[0].get('href')
        q=requests.get(next_url)
        soup=BeautifulSoup(q.content,'html.parser')
        allchunk= soup.find_all("div",{"class":"media-story"})
        for chunk in allchunk:
            if chunk.find("h3",{"class":"search-result-title"})!=None:
                if chunk.h3.find("span",{"class":"yloca-tip"})==None:#not Ad
                    names.append(chunk.h3.a.span.get_text().strip())       
                # Get the numbers of reviews
                    link=chunk.find("span",{"class":"review-count rating-qualifier"})
                    if link!=None:
                        review_count.append(int(link.get_text().strip().split()[0]))
                    else:
                        review_count.append(np.nan)
                # Get the star ratings
                    link=chunk.find("div",{"class":"biz-rating biz-rating-large clearfix"})
                    if link!=None:
                        ratings.append(float(link.img['alt'].split()[0]))
                    else:
                        ratings.append(np.nan)
                # Get price
                    link=chunk.find("span",{"class":"business-attribute price-range"})
                    if link!=None:
                        price.append(link.get_text().strip())
                    else:
                        price.append(np.nan)
                # Get category
                    link=chunk.find("span",{"class":"category-str-list"})
                    if link!=None:
                        cat=link.get_text().strip().split(",")
                        newcat=(",").join([i.strip(' \t\n\r') for i in cat])
                        categories.append(newcat)
                    else:
                        categories.append(np.nan)
    except:
        break
data = pd.DataFrame({"Name":names,"review_count":review_count,"rating":ratings,"price":price,"category":categories})
data.to_csv('yelp_sfo_thai.csv', sep='\t', encoding='utf-8',mode='a', header=False,index=False)
# Out:
# Osha Thai 2208 3.5 $$ Thai,Asian Fusion

# %%
data.head(40)
# Out:
#                               Name  review_count  rating price  \
# 0                        Osha Thai          2208     3.5    $$
# 1                         Lers Ros          2073     4.0    $$
# 2        King Of Thai Noodle House          1717     3.5    $$
# 3                      Marnee Thai          1649     4.0    $$
# 4                         Kin Khao          1602     4.0    $$
# 5             Osha Thai Restaurant          1594     3.5    $$
# 6                      Marnee Thai          1556     4.0    $$
# 7   Farmhouse Kitchen Thai Cuisine          1460     4.0    $$
# 8      Basil Thai Restaurant & Bar          1418     4.0    $$
# 9                        Blackwood          1326     4.0    $$
# 10                   House of Thai          1230     4.0    $$
# 11             Chabaa Thai Cuisine          1176     3.5     $
# 12          Koh Samui & The Monkey          1041     3.5    $$
# 13           King’s Thai Cuisine 1           914     3.5     $
# 14                       Osha Thai           880     3.5    $$
# 15             Chabaa Thai Cuisine           871     3.5    $$
# 16         Sai Jai Thai Restaurant           853     4.0     $
# 17            Thai Time Restaurant           764     4.0     $
# 18                   Lers Ros Thai           691     3.5    $$
# 19                     Modern Thai           677     3.5    $$
# 20            Thai Idea Vegetarian           663     4.5    $$
# 21                         Ploy II           660     3.5    $$
# 22                   Champa Garden           636     4.0    $$
# 23                       Lao Table           601     4.0    $$
# 24         Zen Yai Thai Restaurant           586     4.0     $
# 25            Jitlada Thai Cuisine           582     4.0    $$
# 26        King of Thai Noodle Cafe           574     3.0     $
# 27            Khan Toke Thai House           567     4.0    $$
# 28                      Thai Spice           554     3.5    $$
# 29           Manora’s Thai Cuisine           553     4.0    $$
# 30              Thai House Express           549     3.5    $$
# 31    The Old Siam Thai Restaurant           532     3.5    $$
# 32        Lemon Grass Thai Cuisine           524     3.5    $$
# 33                   Basil Canteen           510     4.0    $$
# 34                Pagan Restaurant           501     4.0    $$
# 35          Regent Thai Restaurant           499     4.0    $$
# 36     Thep Phanom Thai Restaurant           430     3.5    $$
# 37         Sweet Lime Thai Cuisine           427     4.0    $$
# 38             Vanida Thai Kitchen           422     3.5    $$
# 39                         Amphawa           407     4.0    $$
#
#                                 category
# 0                      Thai,Asian Fusion
# 1                         Thai,Wine Bars
# 2                           Thai,Noodles
# 3                                   Thai
# 4                                   Thai
# 5                                   Thai
# 6                                   Thai
# 7          Thai,Comfort Food,Gluten-Free
# 8                              Thai,Bars
# 9   Thai,Breakfast & Brunch,Asian Fusion
# 10                                  Thai
# 11                   Thai,Desserts,Vegan
# 12                                  Thai
# 13                          Thai,Noodles
# 14             Thai,Asian Fusion,Lounges
# 15                                  Thai
# 16                 Thai,Desserts,Seafood
# 17                                  Thai
# 18                                  Thai
# 19                                  Thai
# 20                                  Thai
# 21                          Thai,Noodles
# 22         Asian Fusion,Thai,Sports Bars
# 23                          Laotian,Thai
# 24                                  Thai
# 25                                  Thai
# 26                 Thai,Noodles,Desserts
# 27                       Thai,Salad,Soup
# 28                                  Thai
# 29                             Thai,Bars
# 30                          Thai,Noodles
# 31                                  Thai
# 32                                  Thai
# 33            Thai,Noodles,Cocktail Bars
# 34                          Thai,Burmese
# 35                                  Thai
# 36                                  Thai
# 37                      Thai,Gluten-Free
# 38                                  Thai
# 39                                  Thai
